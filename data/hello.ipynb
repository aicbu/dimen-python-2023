# %%
print('Hello, world')
# Out:
# Hello, world

# %%
test='hello'
print(test)
type(test)
# Out:
# hello
# str

# %%
# numeric types come in two forms
# integers and floats

# integer 
number =10
# float
float = 5.4

type(float)
# Out:
# float

# %% [markdown]
# ### Operators

# %%
36/6
# Out:
# 6.0

# %% [markdown]
# ## Python Collections

# %%
# list
my_list = ['1',3.2,2]
for i in my_list:
    print(type(i))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %%
print(my_list[1:])
# Out:
# [3.2, 2]

# %%
#dict

my_dict = {'one':1,'two':2,'three':3}
print(my_dict['two'])
# Out:
# 2

# %%
! unzip portal-teachingdb-master.zip
# Out:
# Archive:  portal-teachingdb-master.zip
# replace portal-teachingdb-master/surveys2001.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
import pandas as pd

# %%
surveys = pd.read_csv('portal-teachingdb-master/surveys.csv')

# %%
surveys.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length
# 0          1      7   16  1977        2         NL   M             32.0  \
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#get data types for column
surveys["hindfoot_length"][1:10]
# Out:
# 1    33.0
# 2    37.0
# 3    36.0
# 4    35.0
# 5    14.0
# 6     NaN
# 7    37.0
# 8    34.0
# 9    20.0
# Name: hindfoot_length, dtype: float64

# %%
#get all descriptive statistics
surveys.describe()
# Out:
#           record_id         month           day          year       plot_id
# count  35549.000000  35549.000000  35549.000000  35549.000000  35549.000000  \
# mean   17775.000000      6.477847     15.991195   1990.475231     11.397001
# std    10262.256696      3.396925      8.257366      7.493355      6.799406
# min        1.000000      1.000000      1.000000   1977.000000      1.000000
# 25%     8888.000000      4.000000      9.000000   1984.000000      5.000000
# 50%    17775.000000      6.000000     16.000000   1990.000000     11.000000
# 75%    26662.000000     10.000000     23.000000   1997.000000     17.000000
# max    35549.000000     12.000000     31.000000   2002.000000     24.000000
#
#        hindfoot_length        weight
# count     31438.000000  32283.000000
# mean         29.287932     42.672428
# std           9.564759     36.631259
# min           2.000000      4.000000
# 25%          21.000000     20.000000
# 50%          32.000000     37.000000
# ...

# %%
#getting specific des stats
list=["sex","weight"]
grouped_data = surveys.groupby(list)
grouped_data.describe()
# Out:
#            record_id
#                count          mean          std      min       25%      50%
# sex weight
# F   4.0          5.0   7236.200000  2617.293679   4052.0   5346.00   7084.0  \
#     5.0         34.0  12513.323529  8100.089175   2506.0   6986.75   9029.5
#     6.0         88.0  12158.329545  8480.022676    375.0   5595.50   8114.0
#     7.0        262.0  15329.377863  9158.054206    196.0   6392.75  17809.5
#     8.0        300.0  18363.836667  7698.860271     81.0  14144.25  19735.5
# ...              ...           ...          ...      ...       ...      ...
# M   269.0        1.0  13114.000000          NaN  13114.0  13114.00  13114.0
#     270.0        1.0  12729.000000          NaN  12729.0  12729.00  12729.0
#     275.0        1.0  15459.000000          NaN  15459.0  15459.00  15459.0
#     278.0        1.0  12871.000000          NaN  12871.0  12871.00  12871.0
#     280.0        1.0  33049.000000          NaN  33049.0  33049.00  33049.0
#
# ...

# %%
surveys["weight"] = surveys["weight"] *1.1
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length
# 0              1      7   16  1977        2         NL    M             32.0  \
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
surveys["weight"].plot(kind='hist',color='red')
plt.savefig('figs/hist.png',dpi=300)
